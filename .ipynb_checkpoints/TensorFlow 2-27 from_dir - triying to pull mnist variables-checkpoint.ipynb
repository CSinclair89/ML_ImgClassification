# %%
import matplotlib.pyplot as plt
import pathlib
import numpy as np
import PIL
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# Extract and confirm data
dataset_url = "data/train"
data_dir = pathlib.Path(dataset_url).with_suffix("")

# %%
image_count = len(list(data_dir.glob("*/*.jpg")))
image_count
# Out:
# 240

# %%
oval = list(data_dir.glob("oval/*"))
PIL.Image.open(str(oval[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200>

# %%
rectangle = list(data_dir.glob("rectangle/*"))
PIL.Image.open(str(rectangle[35]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200>

# %%
batch_size = 32
img_width = 200
img_height = 200

# Create training dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split = 0.2,
    subset = "training",
    seed = 123,
    image_size = (img_height, img_width),
    batch_size = batch_size)
# Out:
# Found 240 files belonging to 4 classes.
# Using 192 files for training.

# %%
# Create validation dataset

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split = 0.2,
    subset = "validation",
    seed = 123,
    image_size = (img_height, img_width),
    batch_size = batch_size)
# Out:
# Found 240 files belonging to 4 classes.
# Using 48 files for validation.

# %%
# Create class names for plotting
class_names = train_ds.class_names
class_names
# Out:
# ['oval', 'rectangle', 'stickman', 'triangle']

# %%
# Plot images to confirm they are labelled in the proper class
plt.figure(figsize = (10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
# Confirm proper shape of data to fit to model
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 200, 200, 3)
# (32,)

# %%
#Configure dataset for performance w/ prefetch and autotune
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size = AUTOTUNE)

# %%
# Normalize data by bringing RGB values down from range of 0-255 to a range of 0-1
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
# Create learning model (Sequential)

num_classes = len(class_names)

model = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    
    layers.Flatten(),
    
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes)
])

# %%
# Compile learning model
model.compile(optimizer = "adam",
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics = ["accuracy"])

# %%
# Look at summary of model to confirm layers/parameters
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 200, 200, 3)       0
#
#  conv2d (Conv2D)             (None, 200, 200, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 100, 100, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 50, 50, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 40000)             0
#
#  dense (Dense)               (None, 128)               5120128
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 5,144,228
# Trainable params: 5,144,228
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Run learning model
epochs = 15

history = model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = epochs)
# Out:
# Epoch 1/15
# 6/6 [==============================] - 1s 187ms/step - loss: 3.7141 - accuracy: 0.2656 - val_loss: 1.5792 - val_accuracy: 0.2917
# Epoch 2/15
# 6/6 [==============================] - 1s 144ms/step - loss: 1.4085 - accuracy: 0.2604 - val_loss: 1.3927 - val_accuracy: 0.1667
# Epoch 3/15
# 6/6 [==============================] - 1s 138ms/step - loss: 1.3851 - accuracy: 0.2396 - val_loss: 1.3990 - val_accuracy: 0.1667
# Epoch 4/15
# 6/6 [==============================] - 1s 137ms/step - loss: 1.3830 - accuracy: 0.2604 - val_loss: 1.4024 - val_accuracy: 0.1875
# Epoch 5/15
# 6/6 [==============================] - 1s 138ms/step - loss: 1.3663 - accuracy: 0.2865 - val_loss: 1.4120 - val_accuracy: 0.2500
# Epoch 6/15
# 6/6 [==============================] - 1s 145ms/step - loss: 1.3305 - accuracy: 0.4635 - val_loss: 1.4338 - val_accuracy: 0.1667
# Epoch 7/15
# 6/6 [==============================] - 1s 138ms/step - loss: 1.2485 - accuracy: 0.4219 - val_loss: 1.3895 - val_accuracy: 0.2708
# Epoch 8/15
# 6/6 [==============================] - 1s 146ms/step - loss: 1.0910 - accuracy: 0.6250 - val_loss: 1.3979 - val_accuracy: 0.3125
# Epoch 9/15
# 6/6 [==============================] - 1s 144ms/step - loss: 0.8800 - accuracy: 0.6458 - val_loss: 1.4467 - val_accuracy: 0.3333
# Epoch 10/15
# 6/6 [==============================] - 1s 139ms/step - loss: 0.6584 - accuracy: 0.7760 - val_loss: 1.6234 - val_accuracy: 0.3542
# Epoch 11/15
# 6/6 [==============================] - 1s 138ms/step - loss: 0.3771 - accuracy: 0.8958 - val_loss: 2.1823 - val_accuracy: 0.3333
# Epoch 12/15
# 6/6 [==============================] - 1s 140ms/step - loss: 0.1758 - accuracy: 0.9740 - val_loss: 2.8249 - val_accuracy: 0.3750
# Epoch 13/15
# 6/6 [==============================] - 1s 139ms/step - loss: 0.0618 - accuracy: 0.9896 - val_loss: 3.2206 - val_accuracy: 0.4167
# Epoch 14/15
# 6/6 [==============================] - 1s 140ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 3.9814 - val_accuracy: 0.4167
# Epoch 15/15
# 6/6 [==============================] - 1s 141ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 4.3629 - val_accuracy: 0.3958

# %%
# Evaluate model performance
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs_range = range(epochs)

plt.figure(figsize = (8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, accuracy, label = "Training Accuracy")
plt.plot(epochs_range, val_accuracy, label = "Validation Accuracy")
plt.legend(loc = "lower right")
plt.title("Training and Validation Accuracy")

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label = "Training Loss")
plt.plot(epochs_range, val_loss, label = "Validation Loss")
plt.legend(loc = "upper right")
plt.title("Training and Validation Loss")

plt.show()
